# %%
import numpy as np
import torch
from args import parse_args
from baselines import *
from data_utils import (
    get_data_stat,
    get_natural_imbalanced_split_data,
    get_step_imbalanced_split_data,
    load_data,
)
from bat import BatAugmenter
from trainer import NodeClassificationTrainer
from utils import get_model, get_device, print_centered

# %% [markdown]
# # Running Experiment
#
# This script will run experiments on all the combinations of following settings (specified by the global variables below):
#
# | Setting         | (Default) Values                           | Description                                                        |
# | --------------- | ------------------------------------------ | ------------------------------------------------------------------ |
# | `DATASET_SPACE` | `['cora', 'citeseer', 'pubmed']`           | The datasets to use.                                               |
# | `IMB_TYPES`     | `{'step': [10, 20], 'natural': [50, 100]}` | The imbalance types and ratios.                                    |
# | `BAT_MODES`    | `['dummy', 'bat0', 'bat1']`                 | The BAT modes to test, `dummy` means no topological augmentation. |
#
# For other settings, we use the default values specified in `config.yaml`.

# %%
""" Experiment Setup """

import sys

sys.argv = [""]
args = parse_args()

DATASET_SPACE = ["cora", "citeseer", "pubmed"]
MODE_SPACE = ["dummy", "bat0", "bat1"]
IMB_SPACE = {
    "step": [10, 20],
    "natural": [50, 100],
}

# %%
device = get_device(args.gpu_id)
log_width = 100

print(
    f"Run experiment with\n"
    f"  - Datasets:        {DATASET_SPACE}\n"
    f"  - BAT modes:      {MODE_SPACE}\n"
    f"  - Imbalance types: {IMB_SPACE}\n"
)

print_centered("Arguments", 40, fillchar="=")
kwlen = max([len(k) for k in args.__dict__.keys()]) + 1
for keys, values in args.__dict__.items():
    print(f"{keys:{kwlen}}: {values}")
print_centered("", 40, fillchar="=")

# run the experiment

for imb_type in IMB_SPACE.keys():  # loop over imbalance types

    for imb_ratio in IMB_SPACE[imb_type]:  # loop over imbalance ratios

        print_centered(
            f"Experiment: Imbalance Type [{imb_type.title()}] - Ratio [{imb_ratio}]",
            log_width,
            fillchar="/",
            prefix="\n",
        )

        for dataset in DATASET_SPACE:  # loop over datasets

            print_centered(
                f"Dataset [{dataset.title()}] - Independent Runs [{args.n_runs}]", log_width, fillchar="=", prefix="\n"
            )

            args.imb_type = imb_type
            args.imb_ratio = imb_ratio
            args.dataset = dataset

            for bat_mode in MODE_SPACE:  # loop over BAT modes

                print_centered(
                    f"Setting: Dataset [{args.dataset.title()}] - {args.imb_type.title()}IR [{args.imb_ratio}] - BAT [{bat_mode}]",
                    log_width,
                    fillchar="=",
                )

                best_results = []
                for i_run in range(1, args.n_runs + 1):
                    seed = args.seed + i_run

                    # load imbalanced data
                    data = load_data(args.dataset, to_device=device, verbose=args.debug)
                    if args.imb_type == "step":
                        data = get_step_imbalanced_split_data(
                            data,
                            imbratio=args.imb_ratio,
                            random_seed=seed,
                            verbose=args.debug,
                        )
                    elif args.imb_type == "natural":
                        data = get_natural_imbalanced_split_data(
                            data,
                            imbratio=args.imb_ratio,
                            random_seed=seed,
                            verbose=args.debug,
                        )
                    else:
                        raise ValueError(
                            f"imb_type must be one of ['step', 'natural'], got {args.imb_type}."
                        )
                    data = get_data_stat(data, store_in_data=True, verbose=args.debug)

                    # initialize model
                    model = get_model(
                        gnn_arch=args.gnn_arch,
                        feat_dim=data.n_feat,
                        hid_dim=args.hid_dim,
                        out_dim=data.n_class,
                        n_layer=args.n_layer,
                        device=device,
                    )
                    # tobe augmenter
                    augmenter = BatAugmenter(mode=bat_mode, random_state=seed)
                    # trainer
                    trainer = NodeClassificationTrainer(
                        model=model,
                        data=data,
                        device=device,
                        augmenter=augmenter,  # BAT augmentation, to disable, set augmenter=None
                        learning_rate=args.lr,
                        weight_decay=args.weight_decay,
                        train_epoch=args.epochs,
                        early_stop_patience=args.early_stop,
                        eval_freq=1,
                        verbose_freq=None,
                        enable_tqdm=args.tqdm,
                        random_state=seed,
                    )
                    # train the GNN with BAT augmentation
                    best_model = trainer.train()
                    # print best results
                    print (f'Run {i_run}: ', end='')
                    trainer.print_best_results()
                    # save best results
                    best_results.append(trainer.best_eval_results)

                # print the average performance of the best model
                info = f"Avg Test Performance ({args.n_runs} runs): "
                for metric in trainer.eval_metrics.keys():
                    scores = np.array(
                        [
                            best_results[i][metric]["test"] * 100
                            for i in range(len(best_results))
                        ]
                    )
                    info += f" | {metric.upper()}: {scores.mean():.2f} ± {scores.std()/(len(scores)**0.5):.2f}"
                print(info)
# Out:
# Now using GPU #0: Tesla V100-SXM2-32GB
# Run experiment with
#   - Datasets:        ['cora', 'citeseer', 'pubmed']
#   - BAT modes:      ['dummy', 'bat0', 'bat1']
#   - Imbalance types: {'step': [10, 20], 'natural': [50, 100]}
#
# ============== Arguments ==============
# gpu_id       : 0
# seed         : 42
# n_runs       : 5
# debug        : False
# dataset      : cora
# imb_type     : step
# imb_ratio    : 10
# gnn_arch     : GCN
# n_layer      : 3
# hid_dim      : 256
# lr           : 0.01
# weight_decay : 0.0005
# epochs       : 2000
# early_stop   : 200
# tqdm         : False
# bat_mode     : all
# ========================================
#
# ////////////////////////// Experiment: Imbalance Type [Step] - Ratio [10] //////////////////////////
#
# ============================== Dataset [Cora] - Independent Runs [5] ==============================
# ======================= Setting: Dataset [Cora] - StepIR [10] - BAT [dummy] =======================
# Run 1: Best Epoch:   97 | train/val/test | ACC: 100.0/67.20/67.50 | BACC: 100.0/61.93/60.55 | MACRO-F1: 100.0/59.65/59.29 | aug time: 0.00ms
# Run 2: Best Epoch:   67 | train/val/test | ACC: 100.0/65.20/65.00 | BACC: 100.0/60.04/57.70 | MACRO-F1: 100.0/57.21/55.09 | aug time: 0.00ms
# Run 3: Best Epoch:  131 | train/val/test | ACC: 100.0/66.80/67.90 | BACC: 100.0/63.78/61.71 | MACRO-F1: 100.0/62.26/60.08 | aug time: 0.00ms
# Run 4: Best Epoch:   60 | train/val/test | ACC: 100.0/66.40/66.30 | BACC: 100.0/61.60/60.74 | MACRO-F1: 100.0/58.04/59.09 | aug time: 0.00ms
# Run 5: Best Epoch:  151 | train/val/test | ACC: 100.0/63.20/63.70 | BACC: 100.0/57.82/55.99 | MACRO-F1: 100.0/53.30/51.88 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 66.08 ± 0.70 | BACC: 59.34 ± 0.96 | MACRO-F1: 57.09 ± 1.40
# ======================== Setting: Dataset [Cora] - StepIR [10] - BAT [bat0] ========================
# Run 1: Best Epoch:  293 | train/val/test | ACC: 100.0/65.80/66.70 | BACC: 100.0/65.03/64.81 | MACRO-F1: 100.0/62.73/63.07 | aug time: 4.61ms
# Run 2: Best Epoch:  223 | train/val/test | ACC: 100.0/71.00/68.80 | BACC: 100.0/70.88/66.41 | MACRO-F1: 100.0/69.17/64.99 | aug time: 4.54ms
# Run 3: Best Epoch:  279 | train/val/test | ACC: 100.0/72.80/72.70 | BACC: 100.0/72.55/71.14 | MACRO-F1: 100.0/70.37/69.70 | aug time: 4.63ms
# Run 4: Best Epoch:  355 | train/val/test | ACC: 100.0/69.00/70.10 | BACC: 100.0/67.06/67.30 | MACRO-F1: 100.0/64.36/65.40 | aug time: 4.48ms
# Run 5: Best Epoch:   90 | train/val/test | ACC: 100.0/66.60/67.30 | BACC: 100.0/61.18/59.96 | MACRO-F1: 100.0/58.85/58.07 | aug time: 4.61ms
# Avg Test Performance (5 runs):  | ACC: 69.12 ± 0.96 | BACC: 65.92 ± 1.63 | MACRO-F1: 64.24 ± 1.69
# ======================== Setting: Dataset [Cora] - StepIR [10] - BAT [bat1] ========================
# Run 1: Best Epoch:   72 | train/val/test | ACC: 100.0/72.00/72.20 | BACC: 100.0/69.65/68.93 | MACRO-F1: 100.0/66.88/67.10 | aug time: 4.64ms
# Run 2: Best Epoch:  244 | train/val/test | ACC: 100.0/74.00/71.50 | BACC: 100.0/73.93/70.73 | MACRO-F1: 100.0/72.12/69.02 | aug time: 4.57ms
# Run 3: Best Epoch:  117 | train/val/test | ACC: 100.0/73.40/72.70 | BACC: 100.0/75.62/73.93 | MACRO-F1: 100.0/71.35/70.81 | aug time: 4.65ms
# Run 4: Best Epoch:   71 | train/val/test | ACC: 100.0/72.40/72.10 | BACC: 100.0/69.50/67.75 | MACRO-F1: 100.0/68.11/66.80 | aug time: 4.87ms
# Run 5: Best Epoch:   77 | train/val/test | ACC: 100.0/76.20/77.60 | BACC: 100.0/78.03/77.92 | MACRO-F1: 100.0/75.06/76.42 | aug time: 4.53ms
# Avg Test Performance (5 runs):  | ACC: 73.22 ± 0.99 | BACC: 71.85 ± 1.65 | MACRO-F1: 70.03 ± 1.57
#
# ============================ Dataset [Citeseer] - Independent Runs [5] ============================
# ===================== Setting: Dataset [Citeseer] - StepIR [10] - BAT [dummy] =====================
# Run 1: Best Epoch:   57 | train/val/test | ACC: 100.0/45.20/40.30 | BACC: 100.0/42.27/41.85 | MACRO-F1: 100.0/33.57/32.96 | aug time: 0.00ms
# Run 2: Best Epoch:  102 | train/val/test | ACC: 100.0/48.20/42.70 | BACC: 100.0/46.08/44.20 | MACRO-F1: 100.0/39.89/37.52 | aug time: 0.00ms
# Run 3: Best Epoch:   85 | train/val/test | ACC: 100.0/37.20/34.50 | BACC: 100.0/35.72/36.41 | MACRO-F1: 100.0/28.07/27.64 | aug time: 0.00ms
# Run 4: Best Epoch:   66 | train/val/test | ACC: 100.0/38.40/34.20 | BACC: 100.0/36.54/36.79 | MACRO-F1: 100.0/28.47/26.82 | aug time: 0.00ms
# Run 5: Best Epoch:   16 | train/val/test | ACC: 84.85/33.80/31.10 | BACC: 46.67/35.18/34.67 | MACRO-F1: 44.42/22.24/21.48 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 36.56 ± 1.91 | BACC: 38.78 ± 1.62 | MACRO-F1: 29.28 ± 2.46
# ====================== Setting: Dataset [Citeseer] - StepIR [10] - BAT [bat0] ======================
# Run 1: Best Epoch:  304 | train/val/test | ACC: 100.0/61.80/61.70 | BACC: 100.0/59.63/59.91 | MACRO-F1: 100.0/57.94/58.94 | aug time: 4.60ms
# Run 2: Best Epoch:  293 | train/val/test | ACC: 100.0/53.80/52.50 | BACC: 100.0/48.96/49.33 | MACRO-F1: 100.0/46.09/45.37 | aug time: 4.75ms
# Run 3: Best Epoch:  355 | train/val/test | ACC: 100.0/64.20/62.20 | BACC: 100.0/60.36/59.79 | MACRO-F1: 100.0/59.73/59.42 | aug time: 4.66ms
# Run 4: Best Epoch:  138 | train/val/test | ACC: 100.0/47.60/43.50 | BACC: 100.0/47.89/45.05 | MACRO-F1: 100.0/45.38/42.82 | aug time: 4.69ms
# Run 5: Best Epoch:   88 | train/val/test | ACC: 98.48/61.40/58.00 | BACC: 99.17/58.18/55.57 | MACRO-F1: 99.17/57.48/54.99 | aug time: 4.80ms
# Avg Test Performance (5 runs):  | ACC: 55.58 ± 3.11 | BACC: 53.93 ± 2.63 | MACRO-F1: 52.31 ± 3.10
# ====================== Setting: Dataset [Citeseer] - StepIR [10] - BAT [bat1] ======================
# Run 1: Best Epoch:  154 | train/val/test | ACC: 100.0/64.20/62.80 | BACC: 100.0/60.52/59.78 | MACRO-F1: 100.0/59.35/59.13 | aug time: 4.83ms
# Run 2: Best Epoch:   73 | train/val/test | ACC: 96.97/56.80/55.30 | BACC: 98.33/51.08/51.65 | MACRO-F1: 98.35/48.23/47.97 | aug time: 4.92ms
# Run 3: Best Epoch:   94 | train/val/test | ACC: 100.0/63.80/64.80 | BACC: 100.0/61.42/62.18 | MACRO-F1: 100.0/60.44/61.91 | aug time: 5.04ms
# Run 4: Best Epoch:  110 | train/val/test | ACC: 100.0/63.00/61.70 | BACC: 100.0/60.11/60.14 | MACRO-F1: 100.0/59.09/59.37 | aug time: 4.81ms
# Run 5: Best Epoch:  236 | train/val/test | ACC: 100.0/50.80/46.70 | BACC: 100.0/50.73/49.48 | MACRO-F1: 100.0/44.44/43.11 | aug time: 4.93ms
# Avg Test Performance (5 runs):  | ACC: 58.26 ± 2.95 | BACC: 56.64 ± 2.27 | MACRO-F1: 54.30 ± 3.30
#
# ============================= Dataset [Pubmed] - Independent Runs [5] =============================
# ====================== Setting: Dataset [Pubmed] - StepIR [10] - BAT [dummy] ======================
# Run 1: Best Epoch:   60 | train/val/test | ACC: 100.0/57.00/56.00 | BACC: 100.0/64.17/61.63 | MACRO-F1: 100.0/50.42/48.98 | aug time: 0.00ms
# Run 2: Best Epoch:   67 | train/val/test | ACC: 100.0/66.20/66.20 | BACC: 100.0/71.01/69.15 | MACRO-F1: 100.0/64.89/64.67 | aug time: 0.00ms
# Run 3: Best Epoch:  100 | train/val/test | ACC: 100.0/59.60/58.50 | BACC: 100.0/66.70/64.53 | MACRO-F1: 100.0/55.09/53.49 | aug time: 0.00ms
# Run 4: Best Epoch:   95 | train/val/test | ACC: 100.0/70.20/64.00 | BACC: 100.0/75.37/69.35 | MACRO-F1: 100.0/68.57/61.28 | aug time: 0.00ms
# Run 5: Best Epoch:  291 | train/val/test | ACC: 100.0/56.00/53.90 | BACC: 100.0/63.73/60.01 | MACRO-F1: 100.0/48.47/45.26 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 59.72 ± 2.09 | BACC: 64.93 ± 1.70 | MACRO-F1: 54.74 ± 3.26
# ======================= Setting: Dataset [Pubmed] - StepIR [10] - BAT [bat0] =======================
# Run 1: Best Epoch:  133 | train/val/test | ACC: 97.62/73.40/68.30 | BACC: 98.33/74.15/68.50 | MACRO-F1: 92.48/73.30/67.74 | aug time: 6.47ms
# Run 2: Best Epoch:  368 | train/val/test | ACC: 100.0/72.60/68.30 | BACC: 100.0/73.10/69.03 | MACRO-F1: 100.0/72.82/68.59 | aug time: 6.40ms
# Run 3: Best Epoch:   81 | train/val/test | ACC: 97.62/70.60/68.00 | BACC: 98.33/71.11/68.23 | MACRO-F1: 92.48/70.60/67.65 | aug time: 6.39ms
# Run 4: Best Epoch:  187 | train/val/test | ACC: 100.0/71.40/65.40 | BACC: 100.0/72.96/65.86 | MACRO-F1: 100.0/70.64/63.44 | aug time: 6.42ms
# Run 5: Best Epoch:  177 | train/val/test | ACC: 100.0/66.60/62.80 | BACC: 100.0/69.80/65.64 | MACRO-F1: 100.0/66.56/62.27 | aug time: 6.43ms
# Avg Test Performance (5 runs):  | ACC: 66.56 ± 0.97 | BACC: 67.45 ± 0.63 | MACRO-F1: 65.94 ± 1.15
# ======================= Setting: Dataset [Pubmed] - StepIR [10] - BAT [bat1] =======================
# Run 1: Best Epoch:   57 | train/val/test | ACC: 100.0/56.60/54.00 | BACC: 100.0/62.09/57.82 | MACRO-F1: 100.0/50.76/47.12 | aug time: 6.50ms
# Run 2: Best Epoch:   78 | train/val/test | ACC: 100.0/65.00/64.70 | BACC: 100.0/69.34/67.72 | MACRO-F1: 100.0/62.79/62.35 | aug time: 6.55ms
# Run 3: Best Epoch:  260 | train/val/test | ACC: 100.0/72.20/70.50 | BACC: 100.0/73.21/70.22 | MACRO-F1: 100.0/71.67/69.44 | aug time: 6.47ms
# Run 4: Best Epoch:  353 | train/val/test | ACC: 100.0/79.40/74.70 | BACC: 100.0/81.05/76.48 | MACRO-F1: 100.0/78.60/73.62 | aug time: 6.45ms
# Run 5: Best Epoch:  255 | train/val/test | ACC: 100.0/65.20/58.10 | BACC: 100.0/69.58/62.13 | MACRO-F1: 100.0/63.97/55.55 | aug time: 6.55ms
# Avg Test Performance (5 runs):  | ACC: 64.40 ± 3.41 | BACC: 66.87 ± 2.89 | MACRO-F1: 61.62 ± 4.26
#
# ////////////////////////// Experiment: Imbalance Type [Step] - Ratio [20] //////////////////////////
#
# ============================== Dataset [Cora] - Independent Runs [5] ==============================
# ======================= Setting: Dataset [Cora] - StepIR [20] - BAT [dummy] =======================
# Run 1: Best Epoch:  109 | train/val/test | ACC: 100.0/63.20/64.30 | BACC: 100.0/59.18/57.26 | MACRO-F1: 100.0/54.00/53.17 | aug time: 0.00ms
# Run 2: Best Epoch:  243 | train/val/test | ACC: 100.0/61.80/61.10 | BACC: 100.0/54.67/51.83 | MACRO-F1: 100.0/49.80/46.31 | aug time: 0.00ms
# Run 3: Best Epoch:  193 | train/val/test | ACC: 100.0/65.80/66.20 | BACC: 100.0/62.16/59.82 | MACRO-F1: 100.0/59.74/57.35 | aug time: 0.00ms
# Run 4: Best Epoch:   89 | train/val/test | ACC: 100.0/59.80/61.30 | BACC: 100.0/53.72/52.78 | MACRO-F1: 100.0/47.01/47.33 | aug time: 0.00ms
# Run 5: Best Epoch:   89 | train/val/test | ACC: 100.0/60.80/60.50 | BACC: 100.0/53.54/51.65 | MACRO-F1: 100.0/47.07/44.61 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 62.68 ± 0.98 | BACC: 54.67 ± 1.47 | MACRO-F1: 49.75 ± 2.13
# ======================== Setting: Dataset [Cora] - StepIR [20] - BAT [bat0] ========================
# Run 1: Best Epoch:  118 | train/val/test | ACC: 100.0/69.80/69.20 | BACC: 100.0/66.41/65.15 | MACRO-F1: 100.0/65.42/64.47 | aug time: 4.60ms
# Run 2: Best Epoch:  328 | train/val/test | ACC: 100.0/63.00/62.30 | BACC: 100.0/61.09/58.78 | MACRO-F1: 100.0/58.53/56.78 | aug time: 4.41ms
# Run 3: Best Epoch:  196 | train/val/test | ACC: 100.0/72.80/72.50 | BACC: 100.0/72.38/69.84 | MACRO-F1: 100.0/70.26/68.50 | aug time: 4.59ms
# Run 4: Best Epoch:  247 | train/val/test | ACC: 100.0/67.20/68.50 | BACC: 100.0/60.27/61.30 | MACRO-F1: 100.0/59.40/60.72 | aug time: 4.53ms
# Run 5: Best Epoch:  412 | train/val/test | ACC: 100.0/60.40/62.70 | BACC: 100.0/54.29/54.57 | MACRO-F1: 100.0/51.64/52.48 | aug time: 4.52ms
# Avg Test Performance (5 runs):  | ACC: 67.04 ± 1.77 | BACC: 61.93 ± 2.34 | MACRO-F1: 60.59 ± 2.51
# ======================== Setting: Dataset [Cora] - StepIR [20] - BAT [bat1] ========================
# Run 1: Best Epoch:  167 | train/val/test | ACC: 100.0/70.80/70.50 | BACC: 100.0/68.23/67.67 | MACRO-F1: 100.0/65.53/65.32 | aug time: 4.67ms
# Run 2: Best Epoch:  195 | train/val/test | ACC: 100.0/75.60/74.00 | BACC: 100.0/76.92/74.24 | MACRO-F1: 100.0/73.45/71.97 | aug time: 4.55ms
# Run 3: Best Epoch:  159 | train/val/test | ACC: 100.0/74.80/74.70 | BACC: 100.0/73.97/72.44 | MACRO-F1: 100.0/71.93/71.20 | aug time: 4.81ms
# Run 4: Best Epoch:  300 | train/val/test | ACC: 100.0/69.40/69.80 | BACC: 100.0/68.59/68.19 | MACRO-F1: 100.0/65.08/65.96 | aug time: 4.74ms
# Run 5: Best Epoch:   94 | train/val/test | ACC: 100.0/66.00/66.70 | BACC: 100.0/63.67/61.72 | MACRO-F1: 100.0/58.09/57.33 | aug time: 4.62ms
# Avg Test Performance (5 runs):  | ACC: 71.14 ± 1.31 | BACC: 68.85 ± 1.95 | MACRO-F1: 66.36 ± 2.35
#
# ============================ Dataset [Citeseer] - Independent Runs [5] ============================
# ===================== Setting: Dataset [Citeseer] - StepIR [20] - BAT [dummy] =====================
# Run 1: Best Epoch:  199 | train/val/test | ACC: 100.0/34.40/30.80 | BACC: 100.0/34.91/33.86 | MACRO-F1: 100.0/25.05/23.36 | aug time: 0.00ms
# Run 2: Best Epoch:  188 | train/val/test | ACC: 100.0/38.20/33.20 | BACC: 100.0/37.44/35.35 | MACRO-F1: 100.0/29.69/26.51 | aug time: 0.00ms
# Run 3: Best Epoch:   18 | train/val/test | ACC: 90.48/33.40/31.80 | BACC: 47.50/33.88/35.07 | MACRO-F1: 46.44/21.87/21.75 | aug time: 0.00ms
# Run 4: Best Epoch:   14 | train/val/test | ACC: 88.89/34.60/32.10 | BACC: 46.67/35.14/34.59 | MACRO-F1: 45.51/21.72/21.35 | aug time: 0.00ms
# Run 5: Best Epoch:   16 | train/val/test | ACC: 88.89/34.40/31.80 | BACC: 46.67/34.95/35.07 | MACRO-F1: 45.50/22.01/21.49 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 31.94 ± 0.34 | BACC: 34.79 ± 0.23 | MACRO-F1: 22.89 ± 0.87
# ====================== Setting: Dataset [Citeseer] - StepIR [20] - BAT [bat0] ======================
# Run 1: Best Epoch:  252 | train/val/test | ACC: 100.0/58.40/56.10 | BACC: 100.0/58.79/56.33 | MACRO-F1: 100.0/56.22/54.71 | aug time: 4.70ms
# Run 2: Best Epoch:  253 | train/val/test | ACC: 100.0/54.60/50.50 | BACC: 100.0/50.18/48.35 | MACRO-F1: 100.0/47.72/44.88 | aug time: 4.67ms
# Run 3: Best Epoch:  168 | train/val/test | ACC: 100.0/58.00/56.70 | BACC: 100.0/55.97/54.41 | MACRO-F1: 100.0/54.83/53.98 | aug time: 4.89ms
# Run 4: Best Epoch:  304 | train/val/test | ACC: 100.0/49.80/44.60 | BACC: 100.0/47.60/44.16 | MACRO-F1: 100.0/46.72/42.96 | aug time: 4.74ms
# Run 5: Best Epoch:  308 | train/val/test | ACC: 100.0/50.20/49.30 | BACC: 100.0/45.76/47.47 | MACRO-F1: 100.0/45.18/46.23 | aug time: 4.78ms
# Avg Test Performance (5 runs):  | ACC: 51.44 ± 2.02 | BACC: 50.14 ± 2.03 | MACRO-F1: 48.55 ± 2.17
# ====================== Setting: Dataset [Citeseer] - StepIR [20] - BAT [bat1] ======================
# Run 1: Best Epoch:  125 | train/val/test | ACC: 100.0/63.20/62.00 | BACC: 100.0/58.72/58.82 | MACRO-F1: 100.0/58.52/58.63 | aug time: 4.84ms
# Run 2: Best Epoch:   85 | train/val/test | ACC: 100.0/52.20/54.00 | BACC: 100.0/48.69/52.79 | MACRO-F1: 100.0/45.67/48.65 | aug time: 4.94ms
# Run 3: Best Epoch:  315 | train/val/test | ACC: 100.0/54.40/54.20 | BACC: 100.0/51.66/52.45 | MACRO-F1: 100.0/51.15/52.19 | aug time: 4.80ms
# Run 4: Best Epoch:  212 | train/val/test | ACC: 100.0/61.40/60.20 | BACC: 100.0/57.79/57.59 | MACRO-F1: 100.0/57.59/57.61 | aug time: 4.79ms
# Run 5: Best Epoch:  133 | train/val/test | ACC: 100.0/42.40/41.40 | BACC: 100.0/46.11/45.35 | MACRO-F1: 100.0/33.73/33.67 | aug time: 4.96ms
# Avg Test Performance (5 runs):  | ACC: 54.36 ± 3.23 | BACC: 53.40 ± 2.13 | MACRO-F1: 50.15 ± 4.03
#
# ============================= Dataset [Pubmed] - Independent Runs [5] =============================
# ====================== Setting: Dataset [Pubmed] - StepIR [20] - BAT [dummy] ======================
# Run 1: Best Epoch:   99 | train/val/test | ACC: 100.0/56.00/54.40 | BACC: 100.0/62.88/59.69 | MACRO-F1: 100.0/48.95/46.62 | aug time: 0.00ms
# Run 2: Best Epoch:  123 | train/val/test | ACC: 100.0/59.80/57.70 | BACC: 100.0/66.61/62.61 | MACRO-F1: 100.0/55.53/52.73 | aug time: 0.00ms
# Run 3: Best Epoch:  147 | train/val/test | ACC: 100.0/57.40/55.90 | BACC: 100.0/64.69/61.75 | MACRO-F1: 100.0/50.67/48.59 | aug time: 0.00ms
# Run 4: Best Epoch:  196 | train/val/test | ACC: 100.0/56.40/54.00 | BACC: 100.0/64.05/60.62 | MACRO-F1: 100.0/48.82/45.61 | aug time: 0.00ms
# Run 5: Best Epoch:  214 | train/val/test | ACC: 100.0/56.00/54.10 | BACC: 100.0/63.75/60.38 | MACRO-F1: 100.0/48.04/45.23 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 55.22 ± 0.63 | BACC: 61.01 ± 0.46 | MACRO-F1: 47.76 ± 1.23
# ======================= Setting: Dataset [Pubmed] - StepIR [20] - BAT [bat0] =======================
# Run 1: Best Epoch:  195 | train/val/test | ACC: 100.0/67.80/67.20 | BACC: 100.0/69.83/68.28 | MACRO-F1: 100.0/67.42/66.69 | aug time: 6.42ms
# Run 2: Best Epoch:  226 | train/val/test | ACC: 100.0/65.40/64.60 | BACC: 100.0/67.93/66.14 | MACRO-F1: 100.0/64.59/63.54 | aug time: 6.45ms
# Run 3: Best Epoch:  266 | train/val/test | ACC: 100.0/70.80/68.80 | BACC: 100.0/72.49/68.55 | MACRO-F1: 100.0/70.79/68.10 | aug time: 6.43ms
# Run 4: Best Epoch:  130 | train/val/test | ACC: 100.0/64.00/59.80 | BACC: 100.0/64.47/59.91 | MACRO-F1: 100.0/63.04/58.07 | aug time: 6.45ms
# Run 5: Best Epoch:  167 | train/val/test | ACC: 100.0/62.20/56.00 | BACC: 100.0/65.12/58.72 | MACRO-F1: 100.0/61.30/54.29 | aug time: 6.29ms
# Avg Test Performance (5 runs):  | ACC: 63.28 ± 2.12 | BACC: 64.32 ± 1.87 | MACRO-F1: 62.14 ± 2.33
# ======================= Setting: Dataset [Pubmed] - StepIR [20] - BAT [bat1] =======================
# Run 1: Best Epoch:   65 | train/val/test | ACC: 97.56/69.20/69.60 | BACC: 98.33/68.78/67.49 | MACRO-F1: 88.03/68.72/68.28 | aug time: 6.61ms
# Run 2: Best Epoch:   89 | train/val/test | ACC: 100.0/62.00/63.40 | BACC: 100.0/65.52/65.81 | MACRO-F1: 100.0/58.01/59.40 | aug time: 6.61ms
# Run 3: Best Epoch:   79 | train/val/test | ACC: 100.0/67.40/67.60 | BACC: 100.0/71.59/70.72 | MACRO-F1: 100.0/65.86/65.96 | aug time: 6.57ms
# Run 4: Best Epoch:  199 | train/val/test | ACC: 100.0/76.60/71.30 | BACC: 100.0/75.99/70.31 | MACRO-F1: 100.0/76.28/70.65 | aug time: 6.44ms
# Run 5: Best Epoch:   97 | train/val/test | ACC: 100.0/57.00/55.10 | BACC: 100.0/63.65/60.58 | MACRO-F1: 100.0/48.63/45.69 | aug time: 6.37ms
# Avg Test Performance (5 runs):  | ACC: 65.40 ± 2.59 | BACC: 66.98 ± 1.64 | MACRO-F1: 62.00 ± 4.01
#
# //////////////////////// Experiment: Imbalance Type [Natural] - Ratio [50] ////////////////////////
#
# ============================== Dataset [Cora] - Independent Runs [5] ==============================
# ====================== Setting: Dataset [Cora] - NaturalIR [50] - BAT [dummy] ======================
# Run 1: Best Epoch:  179 | train/val/test | ACC: 100.0/70.28/67.20 | BACC: 100.0/58.59/55.43 | MACRO-F1: 100.0/56.60/52.78 | aug time: 0.00ms
# Run 2: Best Epoch:  276 | train/val/test | ACC: 100.0/75.73/75.40 | BACC: 100.0/70.29/69.39 | MACRO-F1: 100.0/70.08/69.58 | aug time: 0.00ms
# Run 3: Best Epoch:   68 | train/val/test | ACC: 99.01/63.29/62.22 | BACC: 85.71/50.84/49.72 | MACRO-F1: 80.95/48.90/47.37 | aug time: 0.00ms
# Run 4: Best Epoch:  267 | train/val/test | ACC: 100.0/71.51/72.95 | BACC: 100.0/62.22/63.93 | MACRO-F1: 100.0/61.98/63.80 | aug time: 0.00ms
# Run 5: Best Epoch:  119 | train/val/test | ACC: 100.0/70.20/72.34 | BACC: 100.0/60.33/62.38 | MACRO-F1: 100.0/59.47/60.70 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 70.02 ± 2.11 | BACC: 60.17 ± 3.07 | MACRO-F1: 58.85 ± 3.53
# ====================== Setting: Dataset [Cora] - NaturalIR [50] - BAT [bat0] ======================
# Run 1: Best Epoch:  269 | train/val/test | ACC: 100.0/73.20/71.34 | BACC: 100.0/68.74/66.75 | MACRO-F1: 100.0/68.13/66.50 | aug time: 4.54ms
# Run 2: Best Epoch:  128 | train/val/test | ACC: 98.02/70.58/69.89 | BACC: 85.16/63.19/61.89 | MACRO-F1: 84.34/62.75/61.61 | aug time: 4.41ms
# Run 3: Best Epoch:  176 | train/val/test | ACC: 100.0/65.59/64.44 | BACC: 100.0/60.69/58.29 | MACRO-F1: 100.0/58.77/56.41 | aug time: 4.42ms
# Run 4: Best Epoch:  187 | train/val/test | ACC: 99.01/69.89/70.73 | BACC: 99.45/65.98/67.65 | MACRO-F1: 99.58/64.41/65.73 | aug time: 4.66ms
# Run 5: Best Epoch:  266 | train/val/test | ACC: 100.0/73.50/74.18 | BACC: 100.0/71.88/70.65 | MACRO-F1: 100.0/71.24/70.06 | aug time: 4.64ms
# Avg Test Performance (5 runs):  | ACC: 70.11 ± 1.42 | BACC: 65.05 ± 1.97 | MACRO-F1: 64.06 ± 2.09
# ====================== Setting: Dataset [Cora] - NaturalIR [50] - BAT [bat1] ======================
# Run 1: Best Epoch:  121 | train/val/test | ACC: 100.0/73.66/70.42 | BACC: 100.0/63.67/60.90 | MACRO-F1: 100.0/61.07/58.24 | aug time: 4.67ms
# Run 2: Best Epoch:  377 | train/val/test | ACC: 100.0/76.34/75.02 | BACC: 100.0/71.17/68.99 | MACRO-F1: 100.0/70.67/69.20 | aug time: 4.73ms
# Run 3: Best Epoch:  107 | train/val/test | ACC: 99.01/67.74/68.58 | BACC: 99.45/59.31/59.83 | MACRO-F1: 99.58/55.43/56.22 | aug time: 4.58ms
# Run 4: Best Epoch:  179 | train/val/test | ACC: 100.0/73.27/73.10 | BACC: 100.0/67.50/67.57 | MACRO-F1: 100.0/64.89/64.13 | aug time: 4.67ms
# Run 5: Best Epoch:  121 | train/val/test | ACC: 100.0/73.58/74.18 | BACC: 100.0/66.90/65.74 | MACRO-F1: 100.0/63.85/62.71 | aug time: 4.74ms
# Avg Test Performance (5 runs):  | ACC: 72.26 ± 1.08 | BACC: 64.61 ± 1.62 | MACRO-F1: 62.10 ± 2.04
#
# ============================ Dataset [Citeseer] - Independent Runs [5] ============================
# ==================== Setting: Dataset [Citeseer] - NaturalIR [50] - BAT [dummy] ====================
# Run 1: Best Epoch:   90 | train/val/test | ACC: 98.88/54.70/55.80 | BACC: 83.33/48.05/49.31 | MACRO-F1: 81.48/40.93/42.39 | aug time: 0.00ms
# Run 2: Best Epoch:  202 | train/val/test | ACC: 100.0/57.29/55.93 | BACC: 100.0/51.72/50.41 | MACRO-F1: 100.0/46.49/45.45 | aug time: 0.00ms
# Run 3: Best Epoch:  118 | train/val/test | ACC: 100.0/52.72/51.42 | BACC: 100.0/45.97/45.00 | MACRO-F1: 100.0/39.02/38.45 | aug time: 0.00ms
# Run 4: Best Epoch:  175 | train/val/test | ACC: 100.0/53.40/55.00 | BACC: 100.0/46.75/48.22 | MACRO-F1: 100.0/40.37/42.32 | aug time: 0.00ms
# Run 5: Best Epoch:  146 | train/val/test | ACC: 100.0/49.01/49.38 | BACC: 100.0/42.20/42.61 | MACRO-F1: 100.0/32.24/32.50 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 53.51 ± 1.18 | BACC: 47.11 ± 1.29 | MACRO-F1: 40.22 ± 1.99
# ==================== Setting: Dataset [Citeseer] - NaturalIR [50] - BAT [bat0] ====================
# Run 1: Best Epoch:  202 | train/val/test | ACC: 100.0/60.20/59.75 | BACC: 100.0/54.96/55.11 | MACRO-F1: 100.0/53.62/54.24 | aug time: 4.87ms
# Run 2: Best Epoch:  167 | train/val/test | ACC: 100.0/54.51/53.64 | BACC: 100.0/50.30/49.79 | MACRO-F1: 100.0/50.09/49.67 | aug time: 4.76ms
# Run 3: Best Epoch:  116 | train/val/test | ACC: 100.0/58.03/57.22 | BACC: 100.0/53.06/51.94 | MACRO-F1: 100.0/52.14/50.84 | aug time: 4.91ms
# Run 4: Best Epoch:   90 | train/val/test | ACC: 100.0/58.22/56.85 | BACC: 100.0/53.28/52.17 | MACRO-F1: 100.0/52.00/51.01 | aug time: 4.82ms
# Run 5: Best Epoch:  198 | train/val/test | ACC: 100.0/57.42/55.68 | BACC: 100.0/53.62/51.76 | MACRO-F1: 100.0/53.86/51.95 | aug time: 4.70ms
# Avg Test Performance (5 runs):  | ACC: 56.63 ± 0.89 | BACC: 52.16 ± 0.76 | MACRO-F1: 51.54 ± 0.68
# ==================== Setting: Dataset [Citeseer] - NaturalIR [50] - BAT [bat1] ====================
# Run 1: Best Epoch:  125 | train/val/test | ACC: 100.0/66.63/64.51 | BACC: 100.0/61.04/59.02 | MACRO-F1: 100.0/60.26/58.01 | aug time: 4.98ms
# Run 2: Best Epoch:  259 | train/val/test | ACC: 100.0/58.16/55.68 | BACC: 100.0/54.68/52.04 | MACRO-F1: 100.0/54.04/51.40 | aug time: 4.82ms
# Run 3: Best Epoch:  126 | train/val/test | ACC: 100.0/66.50/66.42 | BACC: 100.0/60.06/60.31 | MACRO-F1: 100.0/58.12/58.61 | aug time: 4.90ms
# Run 4: Best Epoch:  180 | train/val/test | ACC: 100.0/60.14/59.20 | BACC: 100.0/55.43/54.29 | MACRO-F1: 100.0/54.45/53.02 | aug time: 4.87ms
# Run 5: Best Epoch:  143 | train/val/test | ACC: 100.0/67.80/66.60 | BACC: 100.0/61.49/60.37 | MACRO-F1: 100.0/59.19/57.74 | aug time: 4.88ms
# Avg Test Performance (5 runs):  | ACC: 62.48 ± 1.94 | BACC: 57.21 ± 1.52 | MACRO-F1: 55.76 ± 1.32
#
# ============================= Dataset [Pubmed] - Independent Runs [5] =============================
# ===================== Setting: Dataset [Pubmed] - NaturalIR [50] - BAT [dummy] =====================
# Run 1: Best Epoch:  177 | train/val/test | ACC: 100.0/61.32/60.91 | BACC: 100.0/51.86/51.51 | MACRO-F1: 100.0/46.41/46.08 | aug time: 0.00ms
# Run 2: Best Epoch:  193 | train/val/test | ACC: 100.0/57.31/58.35 | BACC: 100.0/49.05/49.97 | MACRO-F1: 100.0/44.82/45.80 | aug time: 0.00ms
# Run 3: Best Epoch:  170 | train/val/test | ACC: 100.0/54.29/54.49 | BACC: 100.0/47.56/47.68 | MACRO-F1: 100.0/44.53/44.60 | aug time: 0.00ms
# Run 4: Best Epoch:   85 | train/val/test | ACC: 94.83/66.01/65.94 | BACC: 65.33/55.62/55.56 | MACRO-F1: 60.10/49.24/49.20 | aug time: 0.00ms
# Run 5: Best Epoch:  188 | train/val/test | ACC: 100.0/62.81/62.62 | BACC: 100.0/53.13/53.00 | MACRO-F1: 100.0/47.68/47.60 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 60.46 ± 1.73 | BACC: 51.54 ± 1.19 | MACRO-F1: 46.66 ± 0.71
# ===================== Setting: Dataset [Pubmed] - NaturalIR [50] - BAT [bat0] =====================
# Run 1: Best Epoch:  161 | train/val/test | ACC: 100.0/63.34/62.89 | BACC: 100.0/54.81/54.44 | MACRO-F1: 100.0/51.75/51.42 | aug time: 6.49ms
# Run 2: Best Epoch:   40 | train/val/test | ACC: 98.28/48.42/49.19 | BACC: 66.67/40.65/41.30 | MACRO-F1: 64.44/32.76/33.45 | aug time: 6.87ms
# Run 3: Best Epoch:   81 | train/val/test | ACC: 91.38/64.50/64.17 | BACC: 64.00/54.37/54.09 | MACRO-F1: 56.51/48.18/47.91 | aug time: 6.70ms
# Run 4: Best Epoch:   96 | train/val/test | ACC: 98.28/64.51/64.26 | BACC: 99.33/55.15/54.84 | MACRO-F1: 97.44/50.74/50.24 | aug time: 6.62ms
# Run 5: Best Epoch:  272 | train/val/test | ACC: 98.28/65.09/65.08 | BACC: 66.67/54.84/54.83 | MACRO-F1: 66.34/48.49/48.48 | aug time: 6.55ms
# Avg Test Performance (5 runs):  | ACC: 61.12 ± 2.69 | BACC: 51.90 ± 2.37 | MACRO-F1: 46.30 ± 2.93
# ===================== Setting: Dataset [Pubmed] - NaturalIR [50] - BAT [bat1] =====================
# Run 1: Best Epoch:   85 | train/val/test | ACC: 86.21/65.35/65.25 | BACC: 62.00/55.10/55.01 | MACRO-F1: 52.04/48.85/48.74 | aug time: 6.87ms
# Run 2: Best Epoch:  114 | train/val/test | ACC: 100.0/46.77/47.48 | BACC: 100.0/40.52/41.07 | MACRO-F1: 100.0/33.82/34.51 | aug time: 6.70ms
# Run 3: Best Epoch:  161 | train/val/test | ACC: 74.14/65.47/65.15 | BACC: 90.00/58.01/57.53 | MACRO-F1: 66.34/56.83/56.04 | aug time: 6.54ms
# Run 4: Best Epoch:  143 | train/val/test | ACC: 100.0/64.94/65.21 | BACC: 100.0/56.01/56.24 | MACRO-F1: 100.0/52.85/53.09 | aug time: 6.40ms
# Run 5: Best Epoch:  253 | train/val/test | ACC: 94.83/77.18/77.44 | BACC: 98.00/77.31/77.65 | MACRO-F1: 78.97/76.80/77.10 | aug time: 6.55ms
# Avg Test Performance (5 runs):  | ACC: 64.10 ± 4.28 | BACC: 57.50 ± 5.23 | MACRO-F1: 53.90 ± 6.15
#
# //////////////////////// Experiment: Imbalance Type [Natural] - Ratio [100] ////////////////////////
#
# ============================== Dataset [Cora] - Independent Runs [5] ==============================
# ===================== Setting: Dataset [Cora] - NaturalIR [100] - BAT [dummy] =====================
# Run 1: Best Epoch:  101 | train/val/test | ACC: 99.46/71.83/70.65 | BACC: 85.71/61.94/60.90 | MACRO-F1: 84.13/60.55/59.84 | aug time: 0.00ms
# Run 2: Best Epoch:  245 | train/val/test | ACC: 100.0/77.78/74.13 | BACC: 100.0/70.65/66.15 | MACRO-F1: 100.0/70.49/66.56 | aug time: 0.00ms
# Run 3: Best Epoch:  177 | train/val/test | ACC: 99.46/63.33/63.05 | BACC: 99.69/50.73/50.52 | MACRO-F1: 99.77/48.05/47.63 | aug time: 0.00ms
# Run 4: Best Epoch:  246 | train/val/test | ACC: 99.46/67.94/68.59 | BACC: 99.69/58.30/59.41 | MACRO-F1: 99.77/57.30/58.62 | aug time: 0.00ms
# Run 5: Best Epoch:  332 | train/val/test | ACC: 100.0/72.06/74.05 | BACC: 100.0/63.52/64.23 | MACRO-F1: 100.0/65.48/64.81 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 70.09 ± 1.83 | BACC: 60.24 ± 2.42 | MACRO-F1: 59.49 ± 2.97
# ====================== Setting: Dataset [Cora] - NaturalIR [100] - BAT [bat0] ======================
# Run 1: Best Epoch:  393 | train/val/test | ACC: 100.0/75.32/73.97 | BACC: 100.0/68.71/68.10 | MACRO-F1: 100.0/68.82/68.75 | aug time: 4.41ms
# Run 2: Best Epoch:  411 | train/val/test | ACC: 100.0/76.67/72.55 | BACC: 100.0/70.33/65.84 | MACRO-F1: 100.0/69.30/65.30 | aug time: 4.56ms
# Run 3: Best Epoch:  261 | train/val/test | ACC: 99.46/69.13/67.80 | BACC: 99.86/61.65/59.86 | MACRO-F1: 99.77/61.62/59.43 | aug time: 4.67ms
# Run 4: Best Epoch:  206 | train/val/test | ACC: 99.46/71.27/71.04 | BACC: 99.69/63.12/63.09 | MACRO-F1: 99.77/61.85/61.84 | aug time: 4.68ms
# Run 5: Best Epoch:  401 | train/val/test | ACC: 100.0/72.38/74.21 | BACC: 100.0/68.32/68.48 | MACRO-F1: 100.0/68.46/68.36 | aug time: 4.60ms
# Avg Test Performance (5 runs):  | ACC: 71.91 ± 1.05 | BACC: 65.07 ± 1.45 | MACRO-F1: 64.74 ± 1.63
# ====================== Setting: Dataset [Cora] - NaturalIR [100] - BAT [bat1] ======================
# Run 1: Best Epoch:  200 | train/val/test | ACC: 100.0/74.76/73.02 | BACC: 100.0/67.82/65.78 | MACRO-F1: 100.0/65.53/63.38 | aug time: 4.73ms
# Run 2: Best Epoch:  289 | train/val/test | ACC: 100.0/79.21/76.19 | BACC: 100.0/74.07/69.92 | MACRO-F1: 100.0/74.21/70.65 | aug time: 4.73ms
# Run 3: Best Epoch:  407 | train/val/test | ACC: 100.0/73.41/72.63 | BACC: 100.0/66.86/66.41 | MACRO-F1: 100.0/67.03/66.82 | aug time: 4.70ms
# Run 4: Best Epoch:  146 | train/val/test | ACC: 99.46/71.90/72.23 | BACC: 99.69/64.12/64.59 | MACRO-F1: 99.77/61.89/62.62 | aug time: 4.75ms
# Run 5: Best Epoch:  276 | train/val/test | ACC: 99.46/78.25/78.88 | BACC: 99.86/73.96/72.94 | MACRO-F1: 99.60/74.51/73.01 | aug time: 4.63ms
# Avg Test Performance (5 runs):  | ACC: 74.59 ± 1.15 | BACC: 67.93 ± 1.37 | MACRO-F1: 67.30 ± 1.80
#
# ============================ Dataset [Citeseer] - Independent Runs [5] ============================
# =================== Setting: Dataset [Citeseer] - NaturalIR [100] - BAT [dummy] ===================
# Run 1: Best Epoch:  305 | train/val/test | ACC: 100.0/51.39/51.52 | BACC: 100.0/45.25/45.35 | MACRO-F1: 100.0/37.98/38.11 | aug time: 0.00ms
# Run 2: Best Epoch:  188 | train/val/test | ACC: 98.16/52.66/52.59 | BACC: 91.33/46.89/46.65 | MACRO-F1: 93.02/41.92/41.41 | aug time: 0.00ms
# Run 3: Best Epoch:  256 | train/val/test | ACC: 100.0/51.33/49.68 | BACC: 100.0/45.35/43.97 | MACRO-F1: 100.0/38.42/36.61 | aug time: 0.00ms
# Run 4: Best Epoch:  186 | train/val/test | ACC: 98.77/52.41/53.60 | BACC: 83.17/46.01/47.04 | MACRO-F1: 79.71/38.90/39.77 | aug time: 0.00ms
# Run 5: Best Epoch:   85 | train/val/test | ACC: 97.55/48.61/48.30 | BACC: 66.50/42.53/42.25 | MACRO-F1: 63.91/33.68/32.85 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 51.14 ± 0.86 | BACC: 45.05 ± 0.79 | MACRO-F1: 37.75 ± 1.31
# ==================== Setting: Dataset [Citeseer] - NaturalIR [100] - BAT [bat0] ====================
# Run 1: Best Epoch:  151 | train/val/test | ACC: 98.77/60.82/58.78 | BACC: 83.17/54.00/52.12 | MACRO-F1: 81.76/49.73/48.01 | aug time: 4.95ms
# Run 2: Best Epoch:  171 | train/val/test | ACC: 98.16/56.14/57.32 | BACC: 74.83/50.25/51.14 | MACRO-F1: 75.10/47.33/47.99 | aug time: 4.87ms
# Run 3: Best Epoch:  296 | train/val/test | ACC: 100.0/61.52/60.35 | BACC: 100.0/56.67/55.33 | MACRO-F1: 100.0/55.93/54.38 | aug time: 4.89ms
# Run 4: Best Epoch:  238 | train/val/test | ACC: 98.77/60.89/60.04 | BACC: 83.17/55.06/54.13 | MACRO-F1: 79.71/53.13/52.04 | aug time: 4.85ms
# Run 5: Best Epoch:  231 | train/val/test | ACC: 98.77/61.96/61.36 | BACC: 99.67/55.51/54.83 | MACRO-F1: 94.07/52.75/51.50 | aug time: 4.97ms
# Avg Test Performance (5 runs):  | ACC: 59.57 ± 0.62 | BACC: 53.51 ± 0.72 | MACRO-F1: 50.78 ± 1.11
# ==================== Setting: Dataset [Citeseer] - NaturalIR [100] - BAT [bat1] ====================
# Run 1: Best Epoch:  947 | train/val/test | ACC: 100.0/65.25/65.47 | BACC: 100.0/59.67/60.06 | MACRO-F1: 100.0/58.49/59.16 | aug time: 4.95ms
# Run 2: Best Epoch:  694 | train/val/test | ACC: 99.39/60.44/60.48 | BACC: 99.83/56.15/56.02 | MACRO-F1: 99.71/54.88/54.92 | aug time: 4.92ms
# Run 3: Best Epoch:  386 | train/val/test | ACC: 100.0/60.70/60.04 | BACC: 100.0/54.44/53.92 | MACRO-F1: 100.0/51.85/51.16 | aug time: 5.07ms
# Run 4: Best Epoch:  459 | train/val/test | ACC: 100.0/58.80/58.96 | BACC: 100.0/52.09/52.30 | MACRO-F1: 100.0/46.20/46.11 | aug time: 4.99ms
# Run 5: Best Epoch:  162 | train/val/test | ACC: 98.77/59.24/60.16 | BACC: 83.17/52.28/53.13 | MACRO-F1: 82.96/46.40/47.12 | aug time: 4.97ms
# Avg Test Performance (5 runs):  | ACC: 61.02 ± 1.02 | BACC: 55.09 ± 1.24 | MACRO-F1: 51.69 ± 2.18
#
# ============================= Dataset [Pubmed] - Independent Runs [5] =============================
# ==================== Setting: Dataset [Pubmed] - NaturalIR [100] - BAT [dummy] ====================
# Run 1: Best Epoch:  167 | train/val/test | ACC: 99.10/63.44/63.58 | BACC: 66.67/53.46/53.58 | MACRO-F1: 65.08/47.11/47.23 | aug time: 0.00ms
# Run 2: Best Epoch:  161 | train/val/test | ACC: 100.0/53.73/54.93 | BACC: 100.0/45.32/46.29 | MACRO-F1: 100.0/39.01/39.99 | aug time: 0.00ms
# Run 3: Best Epoch:   88 | train/val/test | ACC: 99.10/57.41/57.30 | BACC: 66.67/48.35/48.26 | MACRO-F1: 65.08/42.04/41.97 | aug time: 0.00ms
# Run 4: Best Epoch:   95 | train/val/test | ACC: 99.10/60.80/60.87 | BACC: 66.67/51.23/51.28 | MACRO-F1: 65.08/45.35/45.38 | aug time: 0.00ms
# Run 5: Best Epoch:  148 | train/val/test | ACC: 99.10/61.59/60.69 | BACC: 66.67/51.90/51.14 | MACRO-F1: 65.08/46.14/45.40 | aug time: 0.00ms
# Avg Test Performance (5 runs):  | ACC: 59.47 ± 1.35 | BACC: 50.11 ± 1.14 | MACRO-F1: 43.99 ± 1.17
# ===================== Setting: Dataset [Pubmed] - NaturalIR [100] - BAT [bat0] =====================
# Run 1: Best Epoch:   96 | train/val/test | ACC: 92.79/67.24/67.36 | BACC: 64.33/56.70/56.80 | MACRO-F1: 55.93/50.29/50.37 | aug time: 6.36ms
# Run 2: Best Epoch:  130 | train/val/test | ACC: 99.10/53.62/54.19 | BACC: 66.67/45.15/45.63 | MACRO-F1: 65.08/38.54/39.04 | aug time: 6.31ms
# Run 3: Best Epoch:  223 | train/val/test | ACC: 96.40/67.47/67.95 | BACC: 65.67/56.88/57.29 | MACRO-F1: 60.60/50.38/50.74 | aug time: 6.41ms
# Run 4: Best Epoch:  219 | train/val/test | ACC: 100.0/54.89/53.98 | BACC: 100.0/46.57/45.67 | MACRO-F1: 100.0/41.04/39.77 | aug time: 6.28ms
# Run 5: Best Epoch:  329 | train/val/test | ACC: 98.20/66.01/65.55 | BACC: 66.33/55.65/55.27 | MACRO-F1: 64.75/49.16/48.83 | aug time: 6.36ms
# Avg Test Performance (5 runs):  | ACC: 61.81 ± 2.84 | BACC: 52.13 ± 2.38 | MACRO-F1: 45.75 ± 2.34
# ===================== Setting: Dataset [Pubmed] - NaturalIR [100] - BAT [bat1] =====================
# Run 1: Best Epoch:  284 | train/val/test | ACC: 95.50/66.99/66.80 | BACC: 98.33/56.69/56.53 | MACRO-F1: 92.48/50.68/50.53 | aug time: 6.52ms
# Run 2: Best Epoch:  160 | train/val/test | ACC: 100.0/49.14/49.57 | BACC: 100.0/42.09/42.32 | MACRO-F1: 100.0/35.79/35.82 | aug time: 6.44ms
# Run 3: Best Epoch:  312 | train/val/test | ACC: 98.20/69.58/69.29 | BACC: 99.33/61.15/60.77 | MACRO-F1: 96.63/59.41/58.85 | aug time: 6.54ms
# Run 4: Best Epoch:   89 | train/val/test | ACC: 97.30/65.65/65.24 | BACC: 66.00/55.34/54.99 | MACRO-F1: 61.98/49.09/48.80 | aug time: 6.33ms
# Run 5: Best Epoch:  213 | train/val/test | ACC: 98.20/64.94/64.26 | BACC: 66.33/54.76/54.19 | MACRO-F1: 64.75/48.64/48.17 | aug time: 6.52ms
# Avg Test Performance (5 runs):  | ACC: 63.03 ± 3.10 | BACC: 53.76 ± 2.75 | MACRO-F1: 48.43 ± 3.30
